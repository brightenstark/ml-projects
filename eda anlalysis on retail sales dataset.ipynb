# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('retail_sales_dataset.csv')

# %%
df.head()
# Out:
#    Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 0               1  2023-11-24     CUST001    Male   34           Beauty
# 1               2  2023-02-27     CUST002  Female   26         Clothing
# 2               3  2023-01-13     CUST003    Male   50      Electronics
# 3               4  2023-05-21     CUST004    Male   37         Clothing
# 4               5  2023-05-06     CUST005    Male   30           Beauty
#
#    Quantity  Price per Unit  Total Amount
# 0         3              50           150
# 1         2             500          1000
# 2         1              30            30
# 3         1             500           500
# 4         2              50           100

# %%
df.columns
# Out:
# Index(['Transaction ID', 'Date', 'Customer ID', 'Gender', 'Age',
#        'Product Category', 'Quantity', 'Price per Unit', 'Total Amount'],
#       dtype='object')

# %%
mean1=df['Total Amount'].mean()

# %%
mean1
# Out:
# 456.0

# %%
median1=df['Age'].median()

# %%
median1
# Out:
# 42.0

# %%
mode1=df['Quantity'].mode()

# %%
mode1
# Out:
# 0    4
# Name: Quantity, dtype: int64

# %%
sns.barplot(x=df['Product Category'],y=df['Age'],hue=df['Gender'])
# Out:
# <Axes: xlabel='Product Category', ylabel='Age'>

# %%
sns.heatmap(pd.crosstab(df['Product Category'],df['Quantity']))
# Out:
# <Axes: xlabel='Quantity', ylabel='Product Category'>

# %%
sns.lineplot(x=df['Quantity'],y=df['Price per Unit'])
# Out:
# <Axes: xlabel='Quantity', ylabel='Price per Unit'>

# %%
sns.lineplot(x=df['Product Category'],y=df['Total Amount'])
# Out:
# <Axes: xlabel='Product Category', ylabel='Total Amount'>
